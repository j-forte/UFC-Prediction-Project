# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
import numpy as np
from sklearn.datasets import fetch_california_housing
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_ufc = pd.read_csv('data/ufc-master.csv')

df_gct = pd.read_csv('data/Global_Cybersecurity_Threats_2015-2024.csv')

# %%
df_ufc.head(1)
# Out:
#           RedFighter  BlueFighter  RedOdds  BlueOdds  RedExpectedValue  \
# 0  Alexandre Pantoja  Kai Asakura   -250.0     215.0              40.0
#
#    BlueExpectedValue        Date                Location Country Winner  ...  \
# 0              215.0  2024-12-07  Las Vegas, Nevada, USA     USA    Red  ...
#
#       FinishDetails FinishRound FinishRoundTime  TotalFightTimeSecs  \
# 0  Rear Naked Choke         2.0            2:05               425.0
#
#    RedDecOdds  BlueDecOdds  RSubOdds  BSubOdds  RKOOdds  BKOOdds
# 0       300.0        800.0     150.0    2500.0    400.0    350.0
#
# [1 rows x 118 columns]

# %%
df_ufc['RedFighter'].unique().sum()
# Out:
# "Alexandre PantojaShavkat RakhmonovCiryl GaneBryce MitchellNate LandwehrDominick ReyesVicente LuqueMovsar EvloevRandy BrownChris WeidmanCody DurdenMichael ChiesaClay GuidaKennedy NzechukwuPetr YanYan XiaonanSong KenanWang CongVolkan OezdemirZhang MingyangBaergeng JieleyisiKiru SahotaShi MingNyamjargal TumendemberelLone'er KavanaghXiao LongMaheshateJon JonesCharles OliveiraBo NickalViviane AraujoMauricio RuffyJonathan MartinezJim MillerDavid OnamaMarcin TyburaMickey GallBassil HafezVeronica HardyNeil MagnyGerald MeerschaertGaston BolanosLuana PinheiroMansur Abdul-MalikKarolina KowalkiewiczElizeu Zaleski dos SantosMatthew SemelsbergerCody StamannTresean GoreMelissa MullinsBrandon MorenoErin BlanchfieldCaio MachadoAriane da SilvaMarc-Andre BarriaultMike MalottAiemann ZahabiCharles JourdainJack ShoreAlexandr RomanovSerhiy SideyChad AnheligerJamey-Lyn HorthIlia TopuriaRobert WhittakerMagomed AnkalaevLerone MurphyShara MagomedovIbo AslanGeoff NealMateusz RebeckiAbus MagomedovFarid Basharat
# ...

# %%
df_ufc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6528 entries, 0 to 6527
# Columns: 118 entries, RedFighter to BKOOdds
# dtypes: bool(1), float64(60), int64(43), object(14)
# memory usage: 5.8+ MB

# %%
df_ufc.describe()
# Out:
#            RedOdds     BlueOdds  RedExpectedValue  BlueExpectedValue  \
# count  6301.000000  6302.000000       6301.000000        6302.000000
# mean   -115.711474    59.793240         96.658224         165.054566
# std     277.225783   253.117416         85.891109         137.689177
# min   -2100.000000 -1200.000000          4.761900           8.333300
# 25%    -255.000000  -150.000000         39.215700          66.666700
# 50%    -150.000000   130.000000         66.666700         130.000000
# 75%     130.000000   215.000000        130.000000         215.000000
# max     775.000000  1300.000000        775.000000        1300.000000
#
#        NumberOfRounds  BlueCurrentLoseStreak  BlueCurrentWinStreak  \
# count     6528.000000            6528.000000           6528.000000
# mean         3.185509               0.501072              0.957567
# std          0.577441               0.794303              1.406786
# min          3.000000               0.000000              0.000000
# ...

# %%
df_gct.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 10 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Country                              3000 non-null   object
#  1   Year                                 3000 non-null   int64
#  2   Attack Type                          3000 non-null   object
#  3   Target Industry                      3000 non-null   object
#  4   Financial Loss (in Million $)        3000 non-null   float64
#  5   Number of Affected Users             3000 non-null   int64
#  6   Attack Source                        3000 non-null   object
#  7   Security Vulnerability Type          3000 non-null   object
#  8   Defense Mechanism Used               3000 non-null   object
#  9   Incident Resolution Time (in Hours)  3000 non-null   int64
# dtypes: float64(1), int64(3), object(6)
# memory usage: 234.5+ KB

# %%
df_gct.describe()
# Out:
#               Year  Financial Loss (in Million $)  Number of Affected Users  \
# count  3000.000000                    3000.000000               3000.000000
# mean   2019.570333                      50.492970             504684.136333
# std       2.857932                      28.791415             289944.084972
# min    2015.000000                       0.500000                424.000000
# 25%    2017.000000                      25.757500             255805.250000
# 50%    2020.000000                      50.795000             504513.000000
# 75%    2022.000000                      75.630000             758088.500000
# max    2024.000000                      99.990000             999635.000000
#
#        Incident Resolution Time (in Hours)
# count                          3000.000000
# mean                             36.476000
# std                              20.570768
# min                               1.000000
# 25%                              19.000000
# ...

# %%
df_gct['Security Vulnerability Type'].unique()
# Out:
# array(['Unpatched Software', 'Weak Passwords', 'Social Engineering',
#        'Zero-day'], dtype=object)

# %%
df_gct['Security Vulnerability Type'].value_counts()
# Out:
# Security Vulnerability Type
# Zero-day              785
# Social Engineering    747
# Unpatched Software    738
# Weak Passwords        730
# Name: count, dtype: int64
